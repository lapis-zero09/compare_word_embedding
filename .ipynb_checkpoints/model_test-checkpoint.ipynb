# %%
from gensim.models.word2vec import Word2Vec
from gensim import utils
from glove import Glove
from similar_word import most_similar_dist

# %%
cbow = Word2Vec.load("./model/CBOW.model")
cbow.most_similar(positive=['海外', '営業', '英語'], negative=[], topn=20)
# Out:
# [('配置', 0.45355647802352905),
#  ('先発', 0.3655480146408081),
#  ('課程', 0.3600287437438965),
#  ('ミニスカ', 0.33873677253723145),
#  ('世界的', 0.3342916965484619),
#  ('子供', 0.33099618554115295),
#  ('セリエa', 0.32485830783843994),
#  ('ニューイヤーズ・イブ', 0.3240532875061035),
#  ('構築', 0.3187847137451172),
#  ('成城', 0.3179945647716522),
#  ('分類', 0.3149332106113434),
#  ('川澄奈穂美', 0.31448277831077576),
#  ('チラ', 0.3094601631164551),
#  ('ホテル', 0.30727607011795044),
#  ('8年ぶり', 0.30671823024749756),
#  ('制作', 0.30376845598220825),
#  ('試しに', 0.30192190408706665),
#  ('嫁ぐ', 0.2995319664478302),
#  ('ゆるやか', 0.2980177700519562),
#  ('素顔', 0.29700198769569397)]

# %%
sg = Word2Vec.load("./model/SG.model")
sg.most_similar(positive=['海外', '営業', '英語'], negative=[], topn=20)
# Out:
# [('配置', 0.45355647802352905),
#  ('先発', 0.3655480146408081),
#  ('課程', 0.3600287437438965),
#  ('ミニスカ', 0.33873677253723145),
#  ('世界的', 0.3342916965484619),
#  ('子供', 0.33099618554115295),
#  ('セリエa', 0.32485830783843994),
#  ('ニューイヤーズ・イブ', 0.3240532875061035),
#  ('構築', 0.3187847137451172),
#  ('成城', 0.3179945647716522),
#  ('分類', 0.3149332106113434),
#  ('川澄奈穂美', 0.31448277831077576),
#  ('チラ', 0.3094601631164551),
#  ('ホテル', 0.30727607011795044),
#  ('8年ぶり', 0.30671823024749756),
#  ('制作', 0.30376845598220825),
#  ('試しに', 0.30192190408706665),
#  ('嫁ぐ', 0.2995319664478302),
#  ('ゆるやか', 0.2980177700519562),
#  ('素顔', 0.29700198769569397)]

# %%
cbow_with_hs = Word2Vec.load("./model/CBOW_with_hs.model")
cbow_with_hs.most_similar(positive=['海外', '営業', '英語'], negative=[], topn=20)
# Out:
# [('コンサルティング', 0.49300074577331543),
#  ('英会話', 0.4891873598098755),
#  ('商談', 0.45184844732284546),
#  ('興行成績', 0.4366709887981415),
#  ('投資', 0.4208288788795471),
#  ('国内', 0.41033774614334106),
#  ('大手', 0.40928345918655396),
#  ('銀行', 0.37656933069229126),
#  ('マクドナルド', 0.37428879737854004),
#  ('現地', 0.37300580739974976),
#  ('ヨーロッパ', 0.3715842366218567),
#  ('アジア', 0.36994868516921997),
#  ('法人', 0.3643827438354492),
#  ('つぎ込む', 0.36314985156059265),
#  ('rmt', 0.3541565537452698),
#  ('外資系', 0.3525339365005493),
#  ('シンガポール', 0.3515094220638275),
#  ('顧客', 0.35130590200424194),
#  ('学習', 0.35091662406921387),
#  ('日本法人', 0.3497854471206665)]

# %%
cbow_with_ns = Word2Vec.load("./model/CBOW_with_ns15.model")
cbow_with_ns.most_similar(positive=['海外', '営業', '英語'], negative=[], topn=20)
# Out:
# [('取引', 0.5901567339897156),
#  ('社内', 0.5519546866416931),
#  ('国内', 0.5450115203857422),
#  ('英会話', 0.5427529811859131),
#  ('大学', 0.5308756232261658),
#  ('就職', 0.5144737362861633),
#  ('勉強', 0.5135477781295776),
#  ('取引先', 0.4983792304992676),
#  ('大手', 0.4896126985549927),
#  ('言語', 0.4853058159351349),
#  ('現地', 0.4850444793701172),
#  ('社員', 0.4844452440738678),
#  ('中国語', 0.48287373781204224),
#  ('法人', 0.4818327724933624),
#  ('発音', 0.481831818819046),
#  ('投資', 0.4765412509441376),
#  ('研修', 0.4685256779193878),
#  ('在宅', 0.45923370122909546),
#  ('経営', 0.4588322639465332),
#  ('コンサルティング', 0.4587876796722412)]

# %%
cbow_with_hs_ns = Word2Vec.load("./model/CBOW_with_hs_ns15.model")
cbow_with_hs_ns.most_similar(positive=['海外', '営業', '英語'], negative=[], topn=20)
# Out:
# [('投資', 0.4833008944988251),
#  ('英会話', 0.4426591992378235),
#  ('研修', 0.4206256866455078),
#  ('アジア', 0.4160728454589844),
#  ('勉強', 0.406126469373703),
#  ('学習', 0.40409550070762634),
#  ('現地', 0.3990373909473419),
#  ('コンサルタント', 0.39601391553878784),
#  ('収入', 0.3944935202598572),
#  ('社内', 0.3933321535587311),
#  ('国内', 0.3892199397087097),
#  ('語学', 0.3889053463935852),
#  ('法人', 0.38578230142593384),
#  ('中小企業', 0.3850877583026886),
#  ('起業', 0.383475661277771),
#  ('授業', 0.38077110052108765),
#  ('vendor', 0.38029003143310547),
#  ('rmt', 0.3800632357597351),
#  ('料金', 0.3799452483654022),
#  ('中学', 0.3793860673904419)]

# %%
sg_with_hs = Word2Vec.load("./model/SG_with_hs.model")
sg_with_hs.most_similar(positive=['海外', '営業', '英語'], negative=[], topn=20)
# Out:
# [('英会話', 0.5743021965026855),
#  ('外資系', 0.5580017566680908),
#  ('発音', 0.5279948711395264),
#  ('国内', 0.5210567712783813),
#  ('勉強', 0.5003485679626465),
#  ('法人', 0.4979191720485687),
#  ('大手', 0.4959656894207001),
#  ('半導体', 0.48957130312919617),
#  ('学べる', 0.48872655630111694),
#  ('グローバル', 0.48838984966278076),
#  ('コンサルタント', 0.4859859049320221),
#  ('マン', 0.4755991995334625),
#  ('現地', 0.47517645359039307),
#  ('プロマネ', 0.47321709990501404),
#  ('キャリア', 0.4724541902542114),
#  ('コンサルティング会社', 0.46892815828323364),
#  ('証券会社', 0.46821433305740356),
#  ('ビジネス', 0.4652060568332672),
#  ('金融', 0.4633394479751587),
#  ('コンサルティングファーム', 0.4583726227283478)]

# %%
sg_with_ns = Word2Vec.load("./model/SG_with_ns15.model")
sg_with_ns.most_similar(positive=['海外', '営業', '英語'], negative=[], topn=20)
# Out:
# [('法人', 0.630014181137085),
#  ('国内', 0.6249134540557861),
#  ('証券会社', 0.6042360067367554),
#  ('冬休み', 0.6003375053405762),
#  ('商談', 0.5996975898742676),
#  ('勉強', 0.5907135009765625),
#  ('語学', 0.5881009101867676),
#  ('国際', 0.5873158574104309),
#  ('国際的', 0.5849077701568604),
#  ('パケット定額', 0.5805544853210449),
#  ('マン', 0.5778717398643494),
#  ('外資系', 0.5777236223220825),
#  ('英会話', 0.5771913528442383),
#  ('成田国際空港', 0.5756644010543823),
#  ('マクドナルド', 0.5749722719192505),
#  ('ベンチャー企業', 0.5738098621368408),
#  ('語学力', 0.5736071467399597),
#  ('技術者', 0.5724242925643921),
#  ('定額制', 0.5699853897094727),
#  ('有料化', 0.5693687796592712)]

# %%
sg_with_hs_ns = Word2Vec.load("./model/SG_with_hs_ns15.model")
sg_with_hs_ns.most_similar(positive=['海外', '営業', '英語'], negative=[], topn=20)
# Out:
# [('英会話', 0.6256743669509888),
#  ('国内', 0.5849754810333252),
#  ('国際', 0.5762157440185547),
#  ('勉強', 0.5729621648788452),
#  ('外資系', 0.5674785375595093),
#  ('発音', 0.5555625557899475),
#  ('グローバル', 0.5484088659286499),
#  ('法人', 0.5405935645103455),
#  ('キャリア', 0.5385150909423828),
#  ('たまたま', 0.5356233716011047),
#  ('ビジネス', 0.5316779613494873),
#  ('現地', 0.530596137046814),
#  ('練習', 0.5305052995681763),
#  ('中国語', 0.5240656137466431),
#  ('cdma', 0.5143117904663086),
#  ('入社', 0.5141861438751221),
#  ('語学力', 0.5087576508522034),
#  ('学べる', 0.508248507976532),
#  ('テレコムスクエア', 0.5079659223556519),
#  ('カ国', 0.5057146549224854)]

# %%
# glove = Glove.load("./model/glove.model")
# glove.most_similar(['海外', '営業', '英語'], number=20)
glove = utils.unpickle('./model/glove.model')
most_similar_dist(glove, positive=['海外', '営業', '英語'], negative=[], topn=20)
# Out:
# [('使える', 1.7887511766309387),
#  ('知る', 1.7644044860290822),
#  ('として', 1.6891239968747884),
#  ('でも', 1.5618126390922664),
#  ('自分', 1.5202619221275935),
#  ('音声認識', 1.4289990648018414),
#  ('利用', 1.4036620033893445),
#  ('サービス', 1.393131022043414),
#  ('どう', 1.369545059158733),
#  ('機能', 1.3432994446907203),
#  ('便利', 1.3388831262442351),
#  ('向け', 1.3073715001468131),
#  ('使う', 1.3000808001120383),
#  ('iphone', 1.2869751870815955),
#  ('pc', 1.2514091913014744),
#  ('練習', 1.2483898321677493),
#  ('今', 1.248141656825779),
#  ('だけ', 1.2474476042576848),
#  ('方法', 1.2160967720573188),
#  ('ため', 1.1991029227448693)]

# %%
ppmi = utils.unpickle('./model/ppmi.model')
most_similar_dist(ppmi, positive=['海外', '営業', '英語'], negative=[], topn=20)
# Out:
# [('英会話', 0.17099527349569812),
#  ('発音', 0.1646551799601876),
#  ('音声認識', 0.15607160527651698),
#  ('中国語', 0.15354558053311787),
#  ('マン', 0.13630088898657017),
#  ('日本語', 0.12729881284881883),
#  ('印象づける', 0.10613537442827077),
#  ('no.', 0.10326199294048229),
#  ('商談', 0.101045647690318),
#  ('新しいipad', 0.09880045819046626),
#  ('フランス語', 0.09797681228479554),
#  ('スペイン語', 0.09571728387996231),
#  ('ドイツ語', 0.09551173958175133),
#  ('使える', 0.09369618185286377),
#  ('入社', 0.0934000072009957),
#  ('練習', 0.092253268260207),
#  ('企業', 0.09217344129839666),
#  ('客観的', 0.0917147075021899),
#  ('新卒', 0.09115210787580277),
#  ('韓国語', 0.09005008235992043)]

# %%
svd = utils.unpickle('./model/svd.model')
most_similar_dist(svd, positive=['海外', '営業', '英語'], topn=20)
# Out:
# [('新卒', 0.06471269503329607),
#  ('勤務', 0.055965149268454195),
#  ('転職', 0.05580890232411569),
#  ('年収', 0.05218193805098166),
#  ('大手', 0.051884670298229754),
#  ('入社', 0.05084745019406796),
#  ('1000万円', 0.05043094879849752),
#  ('学ぶ', 0.04708960723905471),
#  ('レンタル', 0.04665312384568082),
#  ('外資系', 0.04551253676679068),
#  ('学習', 0.04367293813727095),
#  ('勤める', 0.04121410032468076),
#  ('図鑑', 0.040799274568837376),
#  ('発音', 0.04017742495204636),
#  ('マン', 0.03856127979245509),
#  ('コンサルタント', 0.038451328867813904),
#  ('経営', 0.037979545403885706),
#  ('iphoneアプリ', 0.03748097888893129),
#  ('社内', 0.037337659687906366),
#  ('練習', 0.03708853984657237)]
